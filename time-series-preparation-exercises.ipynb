# %% [markdown]
# # Preparation Exercises
#
# The end result of this exercise should be a file named prepare.py.

# %% [markdown]
# ## Using your store items data:

# %%
import pandas as pd
import numpy as np
import acquire
import seaborn as sns
from matplotlib import pyplot as plt
from datetime import timedelta, datetime

df = acquire.get_commerce(acquire.get_sales(),acquire.get_items(),acquire.get_stores())

# %%
df.drop(columns = ['Unnamed: 0_x', 'Unnamed: 0_y','Unnamed: 0'], inplace = True)
df.head()
# Out:
#    item_id  sale_amount                      sale_date  sale_id  store_id  \
# 0        1         13.0  Tue, 01 Jan 2013 00:00:00 GMT        1         1
# 1        1         11.0  Wed, 02 Jan 2013 00:00:00 GMT        2         1
# 2        1         14.0  Thu, 03 Jan 2013 00:00:00 GMT        3         1
# 3        1         13.0  Fri, 04 Jan 2013 00:00:00 GMT        4         1
# 4        1         10.0  Sat, 05 Jan 2013 00:00:00 GMT        5         1
#
#             store_address   store_city store_state  store_zipcode item_brand  \
# 0  12125 Alamo Ranch Pkwy  San Antonio          TX          78253   Riceland
# 1  12125 Alamo Ranch Pkwy  San Antonio          TX          78253   Riceland
# 2  12125 Alamo Ranch Pkwy  San Antonio          TX          78253   Riceland
# 3  12125 Alamo Ranch Pkwy  San Antonio          TX          78253   Riceland
# 4  12125 Alamo Ranch Pkwy  San Antonio          TX          78253   Riceland
#
#                         item_name  item_price   item_upc12   item_upc14
# 0  Riceland American Jazmine Rice        0.84  35200264013  35200264013
# 1  Riceland American Jazmine Rice        0.84  35200264013  35200264013
# 2  Riceland American Jazmine Rice        0.84  35200264013  35200264013
# 3  Riceland American Jazmine Rice        0.84  35200264013  35200264013
# 4  Riceland American Jazmine Rice        0.84  35200264013  35200264013

# %%
df.sample(25)
# Out:
#         item_id  sale_amount                      sale_date  sale_id  \
# 574845       32         34.0  Sat, 21 Jan 2017 00:00:00 GMT   574846
# 223456       13        116.0  Sun, 16 Nov 2014 00:00:00 GMT   223457
# 708935       39         34.0  Mon, 24 Mar 2014 00:00:00 GMT   708936
# 362307       20         36.0  Fri, 30 Jan 2015 00:00:00 GMT   362308
# 86974         5         21.0  Sat, 27 Feb 2016 00:00:00 GMT    86975
# 618328       34         21.0  Mon, 15 Feb 2016 00:00:00 GMT   618329
# 213955       12         97.0  Sun, 10 Nov 2013 00:00:00 GMT   213956
# 310016       17         47.0  Wed, 23 Nov 2016 00:00:00 GMT   310017
# 574076       32         26.0  Sun, 14 Dec 2014 00:00:00 GMT   574077
# 194798       11         51.0  Fri, 27 May 2016 00:00:00 GMT   194799
# 9003          1         25.0  Sun, 27 Aug 2017 00:00:00 GMT     9004
# 569343       32         52.0  Wed, 28 Dec 2016 00:00:00 GMT   569344
# 643459       36         59.0  Tue, 09 Dec 2014 00:00:00 GMT   643460
# 378332       21         24.0  Tue, 17 Dec 2013 00:00:00 GMT   378333
# 215063       12         99.0  Tue, 22 Nov 2016 00:00:00 GMT   215064
# 439217       25         93.0  Sat, 05 Sep 2015 00:00:00 GMT   439218
# 48750         3         25.0  Tue, 28 Jun 2016 00:00:00 GMT    48751
# 444863       25         85.0  Sat, 20 Feb 2016 00:00:00 GMT   444864
# 349784       20         62.0  Fri, 16 Oct 2015 00:00:00 GMT   349785
# 652571       36         91.0  Fri, 21 Nov 2014 00:00:00 GMT   652572
# 62439         4         16.0  Sun, 22 Dec 2013 00:00:00 GMT    62440
# 467072       26         39.0  Tue, 13 Dec 2016 00:00:00 GMT   467073
# 128792        8         61.0  Mon, 31 Aug 2015 00:00:00 GMT   128793
# 765549       42         37.0  Tue, 01 Apr 2014 00:00:00 GMT   765550
# 69964         4         28.0  Thu, 31 Jul 2014 00:00:00 GMT    69965
#
#         store_id            store_address   store_city store_state  \
# 574845         5          1520 Austin Hwy  San Antonio          TX
# 223456         3  2118 Fredericksburg Rdj  San Antonio          TX
# 708935         9       735 SW Military Dr  San Antonio          TX
# 362307         9       735 SW Military Dr  San Antonio          TX
# 62439   208528800007  208528800007
# 467072  300436344045  300436344045
# 128792   51600080015   51600080015
# 765549  883978129115  883978129115
# 69964   208528800007  208528800007

# %% [markdown]
# ### 1. Convert date column to datetime format.
# ### 3. Set the index to be the datetime variable.

# %%
df.sale_date = pd.to_datetime(df.sale_date)

df = df.set_index('sale_date').sort_index()

# %%
df.head()
# Out:
#                            item_id  sale_amount  sale_id  store_id  \
# sale_date
# 2013-01-01 00:00:00+00:00        1         13.0        1         1
# 2013-01-01 00:00:00+00:00       12         26.0   211817         7
# 2013-01-01 00:00:00+00:00       46         27.0   832657         7
# 2013-01-01 00:00:00+00:00       12         54.0   213643         8
# 2013-01-01 00:00:00+00:00       12         35.0   215469         9
#
#                                     store_address   store_city store_state  \
# sale_date
# 2013-01-01 00:00:00+00:00  12125 Alamo Ranch Pkwy  San Antonio          TX
# 2013-01-01 00:00:00+00:00  12018 Perrin Beitel Rd  San Antonio          TX
# 2013-01-01 00:00:00+00:00  12018 Perrin Beitel Rd  San Antonio          TX
# 2013-01-01 00:00:00+00:00     15000 San Pedro Ave  San Antonio          TX
# 2013-01-01 00:00:00+00:00      735 SW Military Dr  San Antonio          TX
#
#                            store_zipcode  item_brand  \
# sale_date
# 2013-01-01 00:00:00+00:00          78253    Riceland
# 2013-01-01 00:00:00+00:00          78217     Mueller
# 2013-01-01 00:00:00+00:00          78217  Mama Marys
# 2013-01-01 00:00:00+00:00          78232     Mueller
# 2013-01-01 00:00:00+00:00          78221     Mueller
#
#                                                                    item_name  \
# sale_date
# 2013-01-01 00:00:00+00:00                     Riceland American Jazmine Rice
# 2013-01-01 00:00:00+00:00  Mueller Sport Care Basic Support Level Medium ...
# 2013-01-01 00:00:00+00:00                                        Pizza Sauce
# 2013-01-01 00:00:00+00:00  Mueller Sport Care Basic Support Level Medium ...
# 2013-01-01 00:00:00+00:00  Mueller Sport Care Basic Support Level Medium ...
#
#                            item_price   item_upc12   item_upc14
# sale_date
# 2013-01-01 00:00:00+00:00        0.84  35200264013  35200264013
# 2013-01-01 00:00:00+00:00        8.40  74676640211  74676640211
# 2013-01-01 00:00:00+00:00        4.65  35457770664  35457770664
# 2013-01-01 00:00:00+00:00        8.40  74676640211  74676640211
# 2013-01-01 00:00:00+00:00        8.40  74676640211  74676640211

# %% [markdown]
# ### 2. Plot the distribution of sale_amount and item_price.

# %%
df.sale_amount.hist()
# Out:
# <AxesSubplot:>

# %%
df.item_price.hist()
# Out:
# <AxesSubplot:>

# %% [markdown]
# ### 4. Add a 'month' and 'day of week' column to your dataframe.

# %%
df['month'] = df.index.month
df['day_of_week'] = df.index.day_name()

# %% [markdown]
# ### 5. Add a column to your dataframe, sales_total, which is a derived from sale_amount (total items) and item_price.

# %%
df['sales_total'] = df.sale_amount * df.item_price

# %%
df.head()
# Out:
#                            item_id  sale_amount  sale_id  store_id  \
# sale_date
# 2013-01-01 00:00:00+00:00        1         13.0        1         1
# 2013-01-01 00:00:00+00:00       12         26.0   211817         7
# 2013-01-01 00:00:00+00:00       46         27.0   832657         7
# 2013-01-01 00:00:00+00:00       12         54.0   213643         8
# 2013-01-01 00:00:00+00:00       12         35.0   215469         9
#
#                                     store_address   store_city store_state  \
# sale_date
# 2013-01-01 00:00:00+00:00  12125 Alamo Ranch Pkwy  San Antonio          TX
# 2013-01-01 00:00:00+00:00  12018 Perrin Beitel Rd  San Antonio          TX
# 2013-01-01 00:00:00+00:00  12018 Perrin Beitel Rd  San Antonio          TX
# 2013-01-01 00:00:00+00:00     15000 San Pedro Ave  San Antonio          TX
# 2013-01-01 00:00:00+00:00      735 SW Military Dr  San Antonio          TX
#
#                            store_zipcode  item_brand  \
# sale_date
# 2013-01-01 00:00:00+00:00          78253    Riceland
# 2013-01-01 00:00:00+00:00          78217     Mueller
# 2013-01-01 00:00:00+00:00          78217  Mama Marys
# 2013-01-01 00:00:00+00:00          78232     Mueller
# 2013-01-01 00:00:00+00:00          78221     Mueller
#
#                                                                    item_name  \
# sale_date
# 2013-01-01 00:00:00+00:00                     Riceland American Jazmine Rice
# 2013-01-01 00:00:00+00:00  Mueller Sport Care Basic Support Level Medium ...
# 2013-01-01 00:00:00+00:00                                        Pizza Sauce
# 2013-01-01 00:00:00+00:00  Mueller Sport Care Basic Support Level Medium ...
# 2013-01-01 00:00:00+00:00  Mueller Sport Care Basic Support Level Medium ...
#
#                            item_price   item_upc12   item_upc14  month  \
# sale_date
# 2013-01-01 00:00:00+00:00        0.84  35200264013  35200264013      1
# 2013-01-01 00:00:00+00:00        8.40  74676640211  74676640211      1
# 2013-01-01 00:00:00+00:00        4.65  35457770664  35457770664      1
# 2013-01-01 00:00:00+00:00        8.40  74676640211  74676640211      1
# 2013-01-01 00:00:00+00:00        8.40  74676640211  74676640211      1
#
#                           day_of_week  sales_total
# sale_date
# 2013-01-01 00:00:00+00:00     Tuesday        10.92
# 2013-01-01 00:00:00+00:00     Tuesday       218.40
# 2013-01-01 00:00:00+00:00     Tuesday       125.55
# 2013-01-01 00:00:00+00:00     Tuesday       453.60
# 2013-01-01 00:00:00+00:00     Tuesday       294.00

# %% [markdown]
# ### 6. Make sure all the work that you have done above is reproducible. That is, you should put the code above into separate functions and be able to re-run the functions and get the same results.

# %%
def prep_sales(df):
    '''
    This function prepares sales dataframe.
    '''
    df.sale_date = pd.to_datetime(df.sale_date)
    df = df.set_index('sale_date').sort_index()
    df['month'] = df.index.month
    df['day_of_week'] = df.index.day_name()
    df['sales_total'] = df.sale_amount * df.item_price

# %% [markdown]
# ## Using the OPS data acquired in the Acquire exercises opsd_germany_daily.csv, complete the following:
#
# ### 1. Convert date column to datetime format.
# ### 3. Set the index to be the datetime variable.

# %%
df = acquire.get_opsd_germany()

# %%
df.head()
# Out:
#          Date  Consumption  Wind  Solar  Wind+Solar
# 0  2006-01-01     1069.184   NaN    NaN         NaN
# 1  2006-01-02     1380.521   NaN    NaN         NaN
# 2  2006-01-03     1442.533   NaN    NaN         NaN
# 3  2006-01-04     1457.217   NaN    NaN         NaN
# 4  2006-01-05     1477.131   NaN    NaN         NaN

# %%
df.rename(columns = {'Date':'date','Consumption':'consumption','Wind':'wind','Solar':'solar','Wind+Solar':'wind_and_solar'},inplace = True)
df.date = pd.to_datetime(df.date)
df = df.set_index('date').sort_index()

# %%
df.head()
# Out:
#             consumption  wind  solar  wind_and_solar
# date
# 2006-01-01     1069.184   NaN    NaN             NaN
# 2006-01-02     1380.521   NaN    NaN             NaN
# 2006-01-03     1442.533   NaN    NaN             NaN
# 2006-01-04     1457.217   NaN    NaN             NaN
# 2006-01-05     1477.131   NaN    NaN             NaN

# %% [markdown]
# ### 2. Plot the distribution of each of your variables.

# %%
plt.hist(df.consumption)
# Out:
# (array([  15.,  123.,  360.,  457.,  443.,  740., 1057.,  700.,  426.,
#           62.]),
#  array([ 842.395 ,  929.1123, 1015.8296, 1102.5469, 1189.2642, 1275.9815,
#         1362.6988, 1449.4161, 1536.1334, 1622.8507, 1709.568 ]),
#  <BarContainer object of 10 artists>)

# %%
plt.hist(df.wind)
# Out:
# (array([1105.,  774.,  444.,  254.,  141.,   74.,   49.,   48.,   25.,
#            6.]),
#  array([  5.757 ,  87.8091, 169.8612, 251.9133, 333.9654, 416.0175,
#         498.0696, 580.1217, 662.1738, 744.2259, 826.278 ]),
#  <BarContainer object of 10 artists>)

# %%
plt.hist(df.solar)
# Out:
# (array([414., 341., 228., 230., 272., 271., 198., 149.,  67.,  18.]),
#  array([  1.968 ,  25.9292,  49.8904,  73.8516,  97.8128, 121.774 ,
#         145.7352, 169.6964, 193.6576, 217.6188, 241.58  ]),
#  <BarContainer object of 10 artists>)

# %%
plt.hist(df.wind_and_solar)
# Out:
# (array([162., 492., 665., 372., 207., 120.,  72.,  58.,  29.,  10.]),
#  array([ 21.478 , 104.4858, 187.4936, 270.5014, 353.5092, 436.517 ,
#         519.5248, 602.5326, 685.5404, 768.5482, 851.556 ]),
#  <BarContainer object of 10 artists>)

# %% [markdown]
# ### 4. Add a month and a year column to your dataframe.

# %%
df['month'] = df.index.month

# %%
df['year'] = df.index.year

# %% [markdown]
# ### 5. Fill any missing values.

# %%
df.shape
# Out:
# (4383, 6)

# %%
df.isna().sum()
# Out:
# consumption          0
# wind              1463
# solar             2195
# wind_and_solar    2196
# month                0
# year                 0
# dtype: int64

# %%
df.fillna(0, inplace = True)

# %% [markdown]
# ### 6. Make sure all the work that you have done above is reproducible. That is, you should put the code above into separate functions and be able to re-run the functions and get the same results.

# %%
def prep_opsd_germany(df):
    '''
    This function prepares the German energy production
    '''
    df.rename(columns = {'Date':'date','Consumption':'consumption','Wind':'wind','Solar':'solar','Wind+Solar':'wind_and_solar'},inplace = True)
    df.date = pd.to_datetime(df.date)
    df = df.set_index('date').sort_index()
    df['month'] = df.index.month
    df['year'] = df.index.year
    df.fillna(0, inplace = True)
    return df
